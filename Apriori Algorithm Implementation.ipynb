# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from collections import Counter
import os

# %%
df=pd.read_csv("e-commerce.csv")

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # Pertama, kami akan mengubah nama kolom menjadi lowercase.

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['user_id', 'product_id', 'gender', 'age', 'occupation', 'city_category',
#        'stay_in_current_city_years', 'marital_status', 'product_category_1',
#        'product_category_2', 'product_category_3', 'purchase'],
#       dtype='object')

# %%
df.shape
# Out:
# (47015, 12)

# %% [markdown]
# # Di dataset ini, kami memiliki 47015 baris dan 12 kolom

# %%
df.head()
# Out:
#    user_id product_id gender   age  occupation city_category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   stay_in_current_city_years  marital_status  product_category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    product_category_2  product_category_3  purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %% [markdown]
# # Di dalam "Product_Category_2" dan "Product_Category_3", terdapat null values.

# %%
df.tail()
# Out:
#        user_id product_id gender    age  occupation city_category  \
# 47010  1001228  P00111942      M  26-35           1             C
# 47011  1001228  P00057742      M  26-35           1             C
# 47012  1001228  P00324942      M  26-35           1             C
# 47013  1001228  P00035942      M  26-35           1             C
# 47014  1001228  P00216142      M  26-35           1           NaN
#
#       stay_in_current_city_years  marital_status  product_category_1  \
# 47010                         4+             1.0                 8.0
# 47011                         4+             1.0                 2.0
# 47012                         4+             1.0                 5.0
# 47013                         4+             1.0                 1.0
# 47014                        NaN             NaN                 NaN
#
#        product_category_2  product_category_3  purchase
# 47010                17.0                 NaN   10002.0
# 47011                 8.0                18.0   12742.0
# 47012                 NaN                 NaN    5363.0
# 47013                 5.0                18.0   11642.0
# 47014                 NaN                 NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47015 entries, 0 to 47014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     47015 non-null  int64
#  1   product_id                  47015 non-null  object
#  2   gender                      47015 non-null  object
#  3   age                         47015 non-null  object
#  4   occupation                  47015 non-null  int64
#  5   city_category               47014 non-null  object
#  6   stay_in_current_city_years  47014 non-null  object
#  7   marital_status              47014 non-null  float64
#  8   product_category_1          47014 non-null  float64
#  9   product_category_2          32273 non-null  float64
#  10  product_category_3          14287 non-null  float64
#  11  purchase                    47014 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 4.3+ MB

# %% [markdown]
# # Disini dapat dilihat bahwa occupation adalah integer, seharusnya berbentuk string, maka kita harus merubah tipe datanya.
# # Selanjutnya, kita dapat mengubah Product_Category_2 dan Product_Category_3 ke bentuk integer.

# %%
df.isna().any()
# Out:
# user_id                       False
# product_id                    False
# gender                        False
# age                           False
# occupation                    False
# city_category                  True
# stay_in_current_city_years     True
# marital_status                 True
# product_category_1             True
# product_category_2             True
# product_category_3             True
# purchase                       True
# dtype: bool

# %% [markdown]
# # Kami memiliki nilai "na" dalam city_category, stay_in_current_city_years, marital_status, Product_Category_1, Product_Category_2, Product_Category_3, terakhir purchase.

# %%
df.isnull().sum()
# Out:
# user_id                           0
# product_id                        0
# gender                            0
# age                               0
# occupation                        0
# city_category                     1
# stay_in_current_city_years        1
# marital_status                    1
# product_category_1                1
# product_category_2            14742
# product_category_3            32728
# purchase                          1
# dtype: int64

# %% [markdown]
# # Disini kami memiliki nilai null pada city_category (1) , stay_in_current_city_years (1), marital_status (1), Product_Category_1 (1), Product_Category_2 (14742), Product_Category_3 (32728), terakhir purchase (1).

# %%
df["city_category"].value_counts(dropna=False)
# Out:
# B      19489
# C      14411
# A      13114
# NaN        1
# Name: city_category, dtype: int64

# %%
df["stay_in_current_city_years"].value_counts(dropna=False)
# Out:
# 1      16248
# 2       8716
# 3       8213
# 4+      7342
# 0       6495
# NaN        1
# Name: stay_in_current_city_years, dtype: int64

# %%
df["marital_status"].value_counts(dropna=False)
# Out:
# 0.0    27758
# 1.0    19256
# NaN        1
# Name: marital_status, dtype: int64

# %%
df["product_category_1"].value_counts(dropna=False)
# Out:
# 5.0     13252
# 1.0     11916
# 8.0      9931
# 11.0     2155
# 2.0      2049
# 3.0      1720
# 6.0      1706
# 4.0       983
# 16.0      815
# 15.0      527
# 13.0      440
# 10.0      431
# 12.0      314
# 7.0       299
# 18.0      243
# 14.0      147
# 17.0       51
# 9.0        35
# NaN         1
# Name: product_category_1, dtype: int64

# %%
df["product_category_2"].value_counts(dropna=False)
# Out:
# NaN     14742
# 8.0      5505
# 14.0     4837
# 2.0      4129
# 16.0     3678
# 15.0     3205
# 5.0      2209
# 4.0      2181
# 6.0      1439
# 11.0     1211
# 17.0     1162
# 13.0      904
# 9.0       529
# 12.0      499
# 10.0      255
# 3.0       244
# 18.0      236
# 7.0        50
# Name: product_category_2, dtype: int64

# %%
df["product_category_3"].value_counts(dropna=False)
# Out:
# NaN     32728
# 16.0     2853
# 15.0     2372
# 14.0     1559
# 17.0     1508
# 5.0      1399
# 8.0      1036
# 9.0       990
# 12.0      816
# 13.0      459
# 6.0       414
# 18.0      367
# 4.0       170
# 11.0      153
# 10.0      133
# 3.0        58
# Name: product_category_3, dtype: int64

# %%
df["purchase"].value_counts(dropna=False)
# Out:
# 7075.0     28
# 7089.0     26
# 8021.0     25
# 7989.0     24
# 8044.0     24
#            ..
# 5774.0      1
# 1391.0      1
# 18488.0     1
# 12227.0     1
# 13614.0     1
# Name: purchase, Length: 11545, dtype: int64

# %% [markdown]
# # Sekarang kita mengganti "0" untuk null values.

# %%
df.fillna(0,inplace=True)
df.isnull().sum()
# Out:
# user_id                       0
# product_id                    0
# gender                        0
# age                           0
# occupation                    0
# city_category                 0
# stay_in_current_city_years    0
# marital_status                0
# product_category_1            0
# product_category_2            0
# product_category_3            0
# purchase                      0
# dtype: int64

# %%
df["occupation"]=df["occupation"].astype("object")
df.marital_status=df.marital_status.astype("object")
df.product_category_2=df.product_category_2.astype(int)
df.product_category_3=df.product_category_3.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47015 entries, 0 to 47014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     47015 non-null  int64
#  1   product_id                  47015 non-null  object
#  2   gender                      47015 non-null  object
#  3   age                         47015 non-null  object
#  4   occupation                  47015 non-null  object
#  5   city_category               47015 non-null  object
#  6   stay_in_current_city_years  47015 non-null  object
#  7   marital_status              47015 non-null  object
#  8   product_category_1          47015 non-null  float64
#  9   product_category_2          47015 non-null  int32
#  10  product_category_3          47015 non-null  int32
#  11  purchase                    47015 non-null  float64
# dtypes: float64(2), int32(2), int64(1), object(7)
# memory usage: 3.9+ MB

# %%
df.dtypes
# Out:
# user_id                         int64
# product_id                     object
# gender                         object
# age                            object
# occupation                     object
# city_category                  object
# stay_in_current_city_years     object
# marital_status                 object
# product_category_1            float64
# product_category_2              int32
# product_category_3              int32
# purchase                      float64
# dtype: object

# %% [markdown]
# # Kami memiliki 7 strings, 2 integer dan 2 float.

# %%
df.loc[:,["product_category_1","product_category_2","product_category_3","purchase"]].describe()
# Out:
#        product_category_1  product_category_2  product_category_3  \
# count        47015.000000        47015.000000        47015.000000
# mean             5.300542            6.780772            3.862576
# std              3.715752            6.215472            6.271965
# min              0.000000            0.000000            0.000000
# 25%              1.000000            0.000000            0.000000
# 50%              5.000000            6.000000            0.000000
# 75%              8.000000           14.000000            8.000000
# max             18.000000           18.000000           18.000000
#
#            purchase
# count  47015.000000
# mean    9288.246921
# std     4950.922314
# min        0.000000
# 25%     5863.000000
# 50%     8048.000000
# 75%    12033.000000
# max    23958.000000

# %%
df.columns
# Out:
# Index(['user_id', 'product_id', 'gender', 'age', 'occupation', 'city_category',
#        'stay_in_current_city_years', 'marital_status', 'product_category_1',
#        'product_category_2', 'product_category_3', 'purchase'],
#       dtype='object')

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.countplot(df.gender)
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# # Disini dapat dilihat bahwa Pria lebih banyak berbelanja di e-commerce

# %%
plt.figure(figsize=(10,6))
plt.pie(df.gender.value_counts().values,explode=(0,0),labels=df.gender.value_counts().index,colors=("blue","green"),autopct="%1.1f%%")
plt.title("Pie Chart of Gender")
plt.show()

# %% [markdown]
# # Dapat dilihat juga persentase untuk pria 75.5% dan wanita 24.5%

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.gender,y=df.product_category_1,data=df)
plt.title("Product_Category_1 Bar Graph")
plt.show()

# %% [markdown]
# # Dapat dilihat bahwa pembelian wanita lebih banyak pada product_category_1.

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.gender,y=df.product_category_2,data=df)
plt.title("Product_Category_2 Bar Graph")
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.gender,y=df.product_category_3,data=df)
plt.title("Product_Category_3 Bar Graph")
plt.show()

# %% [markdown]
# # Dapat dilihat bahwa pria lebih banyak berbelanja pada product_category_3.

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sb.barplot(x="gender",y="purchase",data=df,ax=ax)
plt.title("Bar Plot of Gender Base Purchase")
plt.gca().invert_xaxis()
plt.show()

# %%
df.columns
# Out:
# Index(['user_id', 'product_id', 'gender', 'age', 'occupation', 'city_category',
#        'stay_in_current_city_years', 'marital_status', 'product_category_1',
#        'product_category_2', 'product_category_3', 'purchase'],
#       dtype='object')

# %%
f,ax=plt.subplots(figsize=(10,6))
df_age_sorted=df.age.value_counts()
sb.barplot(x=df_age_sorted.index,y=df_age_sorted.values)
plt.title("Number of People by Age Category")
plt.xlabel("Age",size=12)
plt.ylabel("Number of People",size=12)
plt.show()

# %% [markdown]
# # Kita lihat bahwa kebanyakan grup umur 26-35 membeli lebih banyak produk pada e-commerce+

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.age,y=df.product_category_1)
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.age,y=df.product_category_2)
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.age,y=df.product_category_3)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.age,y=df.purchase,hue=df.gender)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.barplot(x=df.gender,y=df.purchase,hue=df.city_category)
plt.title("Product_Category_1 Bar Graph")
plt.show()

# %% [markdown]
# # Kita lihat bahwa wanita membeli lebih banyak pada product_category_1

# %%
df.occupation.value_counts().plot(kind="bar",color="b",alpha=.8,figsize=(15,6))
plt.xlabel("Occupation")
plt.show()

# %% [markdown]
# # Kita lihat disini occupations nomor 0 dan 4 adalah pembeli yang paling banyak

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.countplot(df.city_category)
plt.title("Bar Graph of Cities")
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# # Di kota B, pelanggan membeli lebih banyak produk dibandingkan dengan kota C dan A

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.countplot(x=df.age,hue=df.marital_status)
plt.show()

# %% [markdown]
# # Maried couple menghabiskan lebih sedikit uang pada pembelian produk dibandingkan dengan single people.

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.countplot(x=df.age,hue=df.city_category)
plt.show()

# %%
plt.rcParams["axes.facecolor"]="w"
df["product_id"].value_counts()[:10].plot(kind="barh",color="r",alpha=.5,figsize=(15,6))
plt.title("Bar Graph of Top Ten Products")
plt.xlabel("Number of Solds")
plt.gca().invert_yaxis()
plt.show()

# %%
df.loc[:,["product_category_1","product_category_2","product_category_3","purchase"]].corr()
# Out:
#                     product_category_1  product_category_2  \
# product_category_1            1.000000           -0.042542
# product_category_2           -0.042542            1.000000
# product_category_3           -0.389863            0.098330
# purchase                     -0.319334            0.043232
#
#                     product_category_3  purchase
# product_category_1           -0.389863 -0.319334
# product_category_2            0.098330  0.043232
# product_category_3            1.000000  0.289723
# purchase                      0.289723  1.000000

# %%
f,ax=plt.subplots(figsize=(10,6))
sb.heatmap(df.loc[:,["product_category_1","product_category_2","product_category_3","purchase"]].corr(),annot=True,linewidth=.5,fmt=".3f",ax=ax)
plt.title("Correlations of Variables")
plt.show()

# %%
sb.pairplot(df.loc[:,["product_category_1","product_category_2","product_category_3","purchase"]])
plt.show()

# %%
df.boxplot(column="purchase",by="occupation",figsize=(10,6))
plt.show()
# Out:
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Terdapat outliers di hampir setiap occupations group ini.

# %%
df.boxplot(column="purchase",by="city_category",figsize=(15,8))
plt.show()
# Out:
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Terdapat outliers juga di kota A, B dan C

# %%
df.boxplot(column="purchase",by="marital_status",figsize=(15,8))
plt.show()
# Out:
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Terdapat outliers di setiap grup pada marital_status

# %%
df.boxplot(column="purchase",by="age",figsize=(15,8))
plt.show()
# Out:
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df_product_category_1_normalize=(df.product_category_1-df.product_category_1.mean())/df.product_category_1.std()
df_product_category_2_normalize=(df.product_category_2-df.product_category_2.mean())/df.product_category_2.std()
df_product_category_3_normalize=(df.product_category_3-df.product_category_3.mean())/df.product_category_3.std()
df_purchase_normalize=(df.purchase-df.purchase.mean())/df.purchase.std()
# Sekarang, kami akan me-Normalisasi nilainya.

normalize_data=pd.concat([df_product_category_1_normalize,df_product_category_2_normalize,df_product_category_3_normalize,df_purchase_normalize]
                         ,axis=1)
normalize_data.head()
# Out:
#    product_category_1  product_category_2  product_category_3  purchase
# 0           -0.619132           -1.090950           -0.615848 -0.185470
# 1           -1.157382           -0.125617            1.616308  1.194071
# 2            1.802989           -1.090950           -0.615848 -1.588845
# 3            1.802989            1.161493           -0.615848 -1.662568
# 4            0.726490           -1.090950           -0.615848 -0.266465

# %% [markdown]
# # DATA CLEANING

# %%
#check missing value

round (df.isnull().sum()/ len(df) * 100, 4)
# Out:
# user_id                       0.0
# product_id                    0.0
# gender                        0.0
# age                           0.0
# occupation                    0.0
# city_category                 0.0
# stay_in_current_city_years    0.0
# marital_status                0.0
# product_category_1            0.0
# product_category_2            0.0
# product_category_3            0.0
# purchase                      0.0
# dtype: float64

# %% [markdown]
# # Tidak ada missing value, karena data sudah dibersihkan di awal EDA di atas

# %%
df
# Out:
#        user_id product_id gender    age occupation city_category  \
# 0      1000001  P00069042      F   0-17         10             A
# 1      1000001  P00248942      F   0-17         10             A
# 2      1000001  P00087842      F   0-17         10             A
# 3      1000001  P00085442      F   0-17         10             A
# 4      1000002  P00285442      M    55+         16             C
# ...        ...        ...    ...    ...        ...           ...
# 47010  1001228  P00111942      M  26-35          1             C
# 47011  1001228  P00057742      M  26-35          1             C
# 47012  1001228  P00324942      M  26-35          1             C
# 47013  1001228  P00035942      M  26-35          1             C
# 47014  1001228  P00216142      M  26-35          1             0
#
#       stay_in_current_city_years marital_status  product_category_1  \
# 0                              2              0                 3.0
# 1                              2              0                 1.0
# 2                              2              0                12.0
# 3                              2              0                12.0
# 4                             4+              0                 8.0
# ...                          ...            ...                 ...
# 47010                         4+              1                 8.0
# 47011                         4+              1                 2.0
# 47012                         4+              1                 5.0
# 47013                         4+              1                 1.0
# 47014                          0              0                 0.0
#
#        product_category_2  product_category_3  purchase
# 0                       0                   0    8370.0
# 1                       6                  14   15200.0
# 2                       0                   0    1422.0
# 3                      14                   0    1057.0
# 4                       0                   0    7969.0
# ...                   ...                 ...       ...
# 47010                  17                   0   10002.0
# 47011                   8                  18   12742.0
# 47012                   0                   0    5363.0
# 47013                   5                  18   11642.0
# 47014                   0                   0       0.0
#
# [47015 rows x 12 columns]

# %%
# change data to dataframe
data_df = pd.DataFrame(df)
print (data_df)
# Out:
#        user_id product_id gender    age occupation city_category  \
# 0      1000001  P00069042      F   0-17         10             A
# 1      1000001  P00248942      F   0-17         10             A
# 2      1000001  P00087842      F   0-17         10             A
# 3      1000001  P00085442      F   0-17         10             A
# 4      1000002  P00285442      M    55+         16             C
# ...        ...        ...    ...    ...        ...           ...
# 47010  1001228  P00111942      M  26-35          1             C
# 47011  1001228  P00057742      M  26-35          1             C
# 47012  1001228  P00324942      M  26-35          1             C
# 47013  1001228  P00035942      M  26-35          1             C
# 47014  1001228  P00216142      M  26-35          1             0
#
#       stay_in_current_city_years marital_status  product_category_1  \
# 0                              2              0                 3.0
# 1                              2              0                 1.0
# 2                              2              0                12.0
# 3                              2              0                12.0
# 4                             4+              0                 8.0
# ...                          ...            ...                 ...
# 47010                         4+              1                 8.0
# 47011                         4+              1                 2.0
# 47012                         4+              1                 5.0
# 47013                         4+              1                 1.0
# 47014                          0              0                 0.0
#
#        product_category_2  product_category_3  purchase
# 0                       0                   0    8370.0
# 1                       6                  14   15200.0
# 2                       0                   0    1422.0
# 3                      14                   0    1057.0
# 4                       0                   0    7969.0
# ...                   ...                 ...       ...
# 47010                  17                   0   10002.0
# 47011                   8                  18   12742.0
# 47012                   0                   0    5363.0
# 47013                   5                  18   11642.0
# 47014                   0                   0       0.0
#
# [47015 rows x 12 columns]

# %%
print(df.shape)
# Out:
# (47015, 12)

# %%
# drop missing value
data_dropna = df.dropna()
print(data_dropna.shape)
# Out:
# (47015, 12)

# %%
print(data_dropna)
# Out:
#        user_id product_id gender    age occupation city_category  \
# 0      1000001  P00069042      F   0-17         10             A
# 1      1000001  P00248942      F   0-17         10             A
# 2      1000001  P00087842      F   0-17         10             A
# 3      1000001  P00085442      F   0-17         10             A
# 4      1000002  P00285442      M    55+         16             C
# ...        ...        ...    ...    ...        ...           ...
# 47010  1001228  P00111942      M  26-35          1             C
# 47011  1001228  P00057742      M  26-35          1             C
# 47012  1001228  P00324942      M  26-35          1             C
# 47013  1001228  P00035942      M  26-35          1             C
# 47014  1001228  P00216142      M  26-35          1             0
#
#       stay_in_current_city_years marital_status  product_category_1  \
# 0                              2              0                 3.0
# 1                              2              0                 1.0
# 2                              2              0                12.0
# 3                              2              0                12.0
# 4                             4+              0                 8.0
# ...                          ...            ...                 ...
# 47010                         4+              1                 8.0
# 47011                         4+              1                 2.0
# 47012                         4+              1                 5.0
# 47013                         4+              1                 1.0
# 47014                          0              0                 0.0
#
#        product_category_2  product_category_3  purchase
# 0                       0                   0    8370.0
# 1                       6                  14   15200.0
# 2                       0                   0    1422.0
# 3                      14                   0    1057.0
# 4                       0                   0    7969.0
# ...                   ...                 ...       ...
# 47010                  17                   0   10002.0
# 47011                   8                  18   12742.0
# 47012                   0                   0    5363.0
# 47013                   5                  18   11642.0
# 47014                   0                   0       0.0
#
# [47015 rows x 12 columns]

# %%
#recheck missing value
round (data_dropna.isnull().sum()/ len(data_dropna) * 100, 4)
# Out:
# user_id                       0.0
# product_id                    0.0
# gender                        0.0
# age                           0.0
# occupation                    0.0
# city_category                 0.0
# stay_in_current_city_years    0.0
# marital_status                0.0
# product_category_1            0.0
# product_category_2            0.0
# product_category_3            0.0
# purchase                      0.0
# dtype: float64

# %%
df[['product_category_2', 'product_category_3']].isnull().sum()
# Out:
# product_category_2    0
# product_category_3    0
# dtype: int64

# %%
data_dropna[['product_category_2', 'product_category_3']].isnull().sum()
# Out:
# product_category_2    0
# product_category_3    0
# dtype: int64

# %% [markdown]
# # DATA REDUCTION

# %%
product = data_dropna

# %%
product
# Out:
#        user_id product_id gender    age occupation city_category  \
# 0      1000001  P00069042      F   0-17         10             A
# 1      1000001  P00248942      F   0-17         10             A
# 2      1000001  P00087842      F   0-17         10             A
# 3      1000001  P00085442      F   0-17         10             A
# 4      1000002  P00285442      M    55+         16             C
# ...        ...        ...    ...    ...        ...           ...
# 47010  1001228  P00111942      M  26-35          1             C
# 47011  1001228  P00057742      M  26-35          1             C
# 47012  1001228  P00324942      M  26-35          1             C
# 47013  1001228  P00035942      M  26-35          1             C
# 47014  1001228  P00216142      M  26-35          1             0
#
#       stay_in_current_city_years marital_status  product_category_1  \
# 0                              2              0                 3.0
# 1                              2              0                 1.0
# 2                              2              0                12.0
# 3                              2              0                12.0
# 4                             4+              0                 8.0
# ...                          ...            ...                 ...
# 47010                         4+              1                 8.0
# 47011                         4+              1                 2.0
# 47012                         4+              1                 5.0
# 47013                         4+              1                 1.0
# 47014                          0              0                 0.0
#
#        product_category_2  product_category_3  purchase
# 0                       0                   0    8370.0
# 1                       6                  14   15200.0
# 2                       0                   0    1422.0
# 3                      14                   0    1057.0
# 4                       0                   0    7969.0
# ...                   ...                 ...       ...
# 47010                  17                   0   10002.0
# 47011                   8                  18   12742.0
# 47012                   0                   0    5363.0
# 47013                   5                  18   11642.0
# 47014                   0                   0       0.0
#
# [47015 rows x 12 columns]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
df=pd.read_csv("e-commerce.csv")
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
print("Number of unique users:",len(df.User_ID.unique()))
print("Number of unique products:",len(df.Product_ID.unique()))
print("Number of unique occupations recorded:",len(df.Occupation.unique()))
# Out:
# Number of unique users: 5397
# Number of unique products: 3065
# Number of unique occupations recorded: 21

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(0)
df['Product_Category_3'] = df['Product_Category_3'].fillna(0)

# %%
user_profiles=df[['User_ID','Gender','Age','Occupation','City_Category','Stay_In_Current_City_Years','Marital_Status']].drop_duplicates()
user_profiles.head()
# Out:
#    User_ID Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0  1000001      F   0-17          10             A                          2
# 4  1000002      M    55+          16             C                         4+
# 5  1000003      M  26-35          15             A                          3
# 6  1000004      M  46-50           7             B                          2
# 9  1000005      M  26-35          20             A                          1
#
#    Marital_Status
# 0             0.0
# 4             0.0
# 5             0.0
# 6             1.0
# 9             1.0

# %%
import matplotlib.pyplot as plt

columns=['Gender','Age','City_Category','Stay_In_Current_City_Years','Marital_Status']
fig = plt.figure(figsize=(30, 20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, (len(columns)**2)+1):
    ax=fig.add_subplot(len(columns), len(columns), i)
    ax=sns.countplot(user_profiles[columns[int((i-1)/len(columns))]],hue=columns[((i-1)%len(columns))],data=user_profiles)
    ax=plt.legend(loc='best')

plt.show()

# %%
columns=['Age','Gender','Occupation','City_Category','Stay_In_Current_City_Years','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3']
fig = plt.figure(figsize=(30, 20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, (len(columns))+1):
    temp=df[['User_ID',columns[i-1],'Purchase']].groupby(['User_ID',columns[i-1]]).agg('sum').reset_index().sort_values('Purchase',ascending=False)
    temp=temp.sort_values(columns[i-1]) 
    ax=fig.add_subplot(3, 3, i)
    ax=sns.boxplot(x=columns[i-1],y=np.log(temp.Purchase),data=temp)

# %%
columns=['Age','Gender','Occupation','City_Category','Stay_In_Current_City_Years','Marital_Status']
fig = plt.figure(figsize=(20, 10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, (len(columns))+1):
    label=[]
    temp=df[['User_ID',columns[i-1],'Purchase']].groupby(['User_ID',columns[i-1]]).agg('sum').reset_index().sort_values('Purchase',ascending=False)
    ax=fig.add_subplot(2, 3, i)
    for j in list(df[columns[i-1]].unique()):
        hist_data=temp[temp[columns[i-1]]==j]
        ax=sns.distplot(np.log(hist_data.Purchase),hist=False,label=j)
        label.append(j)
# Out:
# C:\Users\ITD-STU\anaconda3\lib\site-packages\seaborn\distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\ITD-STU\anaconda3\lib\site-packages\seaborn\distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\ITD-STU\anaconda3\lib\site-packages\seaborn\distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\ITD-STU\anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def product_popularity_barplot(Category):    
    by_cat=df[['Product_Category_1',Category,'User_ID']].groupby(['Product_Category_1',Category]).agg('count').reset_index()
    by_cat=by_cat.pivot(index='Product_Category_1',columns=Category)['User_ID'].reset_index()

    for i in by_cat.columns[1:]:
        by_cat[i] = by_cat[i]/df[df[Category]==i].count()[0]

    by_cat=by_cat.melt('Product_Category_1', var_name=Category, value_name='Val')

    columns=by_cat[Category].unique().tolist()
    fig,ax=plt.subplots(1,len(columns),sharey=True)
    fig.set_figheight(5)
    fig.set_figwidth(8*len(columns))
    fig.subplots_adjust(hspace=0.2, wspace=0.2)
    for i in range(0, (len(columns))):
        temp=by_cat[by_cat[Category]==columns[i]]
        title=str(Category)+':'+str(columns[i])  
        sns.barplot(x='Product_Category_1',y='Val',data=temp,ax=ax[i])
        ax[i].set_title(title,fontsize=20)

# %%
product_popularity_barplot('Gender')
product_popularity_barplot('Age')
product_popularity_barplot('City_Category')
product_popularity_barplot('Stay_In_Current_City_Years')
product_popularity_barplot('Marital_Status')

# %%
purchase_by_prod_id=df[['Product_ID','Purchase']].groupby('Product_ID').agg('sum').reset_index().sort_values('Purchase',ascending=False).head(10)
print(purchase_by_prod_id.head(10))
# Out:
#      Product_ID   Purchase
# 222   P00025442  2652610.0
# 514   P00059442  2289112.0
# 861   P00112142  2283625.0
# 848   P00110742  2198364.0
# 1478  P00184942  2106825.0
# 850   P00110942  2060874.0
# 2097  P00255842  1975879.0
# 406   P00046742  1917367.0
# 1936  P00237542  1885470.0
# 1143  P00145042  1829611.0

# %%
purchase_by_user=df[['User_ID','Purchase']].groupby('User_ID').agg('sum').reset_index().sort_values('Purchase',ascending=False).head(10)
temp=df[df['User_ID'].isin(list(purchase_by_user['User_ID']))][['User_ID','Gender','Age','Occupation','City_Category',
                                                          'Stay_In_Current_City_Years','Marital_Status']].drop_duplicates()
temp.merge(purchase_by_user,how='left').sort_values('Purchase',ascending=False)
# Out:
#    User_ID Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 5  1000889      M  46-50          20             A                          1
# 2  1000549      M  26-35           6             A                          3
# 1  1000424      M  26-35          17             A                          3
# 7  1001181      M  36-45           7             A                          3
# 6  1001015      M  36-45           3             A                         4+
# 4  1000869      M  18-25          20             A                         4+
# 9  1004277      M  36-45          16             A                          0
# 8  1001680      M  26-35          20             A                          3
# 3  1000550      M  46-50           8             B                          1
# 0  1000195      M  26-35          12             B                         4+
#
#    Marital_Status  Purchase
# 5             0.0  963939.0
# 2             0.0  910819.0
# 1             0.0  902832.0
# 7             1.0  884138.0
# 6             1.0  843827.0
# 4             1.0  829800.0
# 9             0.0  817900.0
# 8             1.0  804346.0
# 3             1.0  797329.0
# 0             1.0  776450.0

# %%
purchase_by_user=df[['User_ID','Purchase']].groupby('User_ID').agg('sum').reset_index().sort_values('Purchase',ascending=False)
sns.distplot(purchase_by_user['Purchase'])
plt.show()

# %% [markdown]
# # Implementing Apriori Algorithm

# %%
#import library
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
#mlxtend melakukan import fungsi apriori dan association_rules

# %%
# Merancang kondisi yang mengindikasi product dengan rating terpopular

product["Populer"] = product["purchase"] > 7700
product[10:15]

product[product["user_id"] == 1][:5]
# Out:
# Empty DataFrame
# Columns: [user_id, product_id, gender, age, occupation, city_category, stay_in_current_city_years, marital_status, product_category_1, product_category_2, product_category_3, purchase, Populer]
# Index: []

# %%
product.head()
# Out:
#    user_id product_id gender   age occupation city_category  \
# 0  1000001  P00069042      F  0-17         10             A
# 1  1000001  P00248942      F  0-17         10             A
# 2  1000001  P00087842      F  0-17         10             A
# 3  1000001  P00085442      F  0-17         10             A
# 4  1000002  P00285442      M   55+         16             C
#
#   stay_in_current_city_years marital_status  product_category_1  \
# 0                          2              0                 3.0
# 1                          2              0                 1.0
# 2                          2              0                12.0
# 3                          2              0                12.0
# 4                         4+              0                 8.0
#
#    product_category_2  product_category_3  purchase  Populer
# 0                   0                   0    8370.0     True
# 1                   6                  14   15200.0     True
# 2                   0                   0    1422.0    False
# 3                  14                   0    1057.0    False
# 4                   0                   0    7969.0     True

# %%
# Menampilkan product yang popular

popular_product = product[product["Populer"]]
popular_product.head()
# Out:
#    user_id product_id gender    age occupation city_category  \
# 0  1000001  P00069042      F   0-17         10             A
# 1  1000001  P00248942      F   0-17         10             A
# 4  1000002  P00285442      M    55+         16             C
# 5  1000003  P00193542      M  26-35         15             A
# 6  1000004  P00184942      M  46-50          7             B
#
#   stay_in_current_city_years marital_status  product_category_1  \
# 0                          2              0                 3.0
# 1                          2              0                 1.0
# 4                         4+              0                 8.0
# 5                          3              0                 1.0
# 6                          2              1                 1.0
#
#    product_category_2  product_category_3  purchase  Populer
# 0                   0                   0    8370.0     True
# 1                   6                  14   15200.0     True
# 4                   0                   0    7969.0     True
# 5                   2                   0   15227.0     True
# 6                   8                  17   19215.0     True

# %%
# Memasukkan product yang dikomentari pengguna ke dalam collection
# frozenset Freeze collection

favor_reviews_by_customers = dict((k, frozenset(v.values)) for k, v in popular_product.groupby("user_id")["product_id"])

# %%
# Menghitung jumlah rekomendasi producr

num_favor_reviews_by_customers = popular_product[["product_id", "Populer"]].groupby("product_id").sum()

# %%
#mengurutkan product berdasarkan kolom populer
num_favor_reviews_by_customers.sort_values(by="Populer", ascending=False).head()
# Out:
#             Populer
# product_id
# P00025442     153.0
# P00112142     141.0
# P00110742     133.0
# P00059442     127.0
# P00184942     126.0

# %%
# Membuat initial frequent itemset


from collections import defaultdict
import sys
def find_frequent_itemsets(favor_reviews_by_customers ,k_itemsets,min_support):
    counts = defaultdict(int)
  
    for user,review in favor_reviews_by_customers.items():
      
        for itemset in k_itemsets:
            if itemset.issubset(review):
                for other_reviewed_movie in review-itemset:
                    current_superset = itemset|frozenset((other_reviewed_movie,))
                    counts[current_superset] += 1
    return dict([(itemset,frequence) for itemset,frequence in counts.items() if frequence >= min_support])

# %%
frequent_itemsets={}

# %%
min_support = 50

# %%
frequent_itemsets = {} 
min_support = 50

# Frequent item dengan length 1
frequent_itemsets[1] = dict((frozenset((product_id,)), row["Populer"])
                                for product_id, row in num_favor_reviews_by_customers.iterrows()
                                if row["Populer"] > min_support)

print("Terdapat {} product dengan lebih dari {} favorable reviews".format(len(frequent_itemsets[1]), min_support))
sys.stdout.flush()
# Out:
# Terdapat 100 product dengan lebih dari 50 favorable reviews
